# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
import pandas as pd
from src.anomaly_detection import isolation_forest_detection
from src.visualization import plot_anomaly_scores

df = pd.read_csv('../data/raw/creditcard.csv')

X = df.drop(columns=['Class'])

preds, scores = isolation_forest_detection(X, contamination=0.01)

df['iforest_anomaly'] = preds
df['anomaly_score'] = scores

df[['anomaly_score', 'iforest_anomaly']].to_csv(
    '../results/anomaly_scores.csv', index=False
)

plot_anomaly_scores(scores, '../results/anomaly_plots.png')
